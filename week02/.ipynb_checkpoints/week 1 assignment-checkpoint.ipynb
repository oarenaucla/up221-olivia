# %% [markdown]
# **Exploration of Philadelphia Housing Data**
#
# This dataset of afforable housing units was pulled from Philadelphia's Open Data Portal. Philadelphia's  Division of Housing and Community Development (DHCD) provides funding for the rehabilitation and building of housing below market-rate. This dataset includes the number and location of affordable housing units (sale, rental, and supportive) built between 1994 to August 2019. The code below includes an exploration of the housing projects funded within Philadelphia to, hopfeully, get a sense of how and where the City is spending money to help people with fewer economic resources afford housing.

# %% [markdown]
# First, I import the pandas and geopandas libraries because I want to visualize the housing data.

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# The nexxt step is importing and reading in my csv of the specific affordable housing developments. I created a new variable affhousing and read in the CSV file with geopandas.

# %%
affhousing=gpd.read_file('ah.csv')

# %% [markdown]
# It seemed to have worked, but just to double check, I checked the type of data. It turned out to be a dataframe!

# %%
type(affhousing)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# To get a broader sense of the size of the dataset is to run .shape, which will show the number of rows and columns.

# %%
affhousing.shape
# Out:
# (401, 11)

# %% [markdown]
# So, there are more observations for a limited number of variables, which makes sense because this is an inventory of projects that the City funded in 25 years through specific funds. Another check to begin seeing the full scope of the data is to look at some of the initial rows and columns. I looked a few different cuts of the data using head, tail, and sample commands.

# %%
affhousing
# Out:
#     OBJECTID FISCAL_YEAR_COMPLETE                           PROJECT_NAME  \
# 0          1                 2019  Gloria Casarez Residence (1315 N 8th)
# 1          2                 2019                 Roberto Clemente Homes
# 2          3                 2019           Henry Avenue Senior Campus I
# 3          4                 2019                      Villas Del Caribe
# 4          5                 2019                         Cantrell Place
# ..       ...                  ...                                    ...
# 396      397                 1995              Youthbuild - Point Breeze
# 397      398                                     Capacity Building Grant
# 398      399                                     Capacity Building Grant
# 399      400                                     Capacity Building Grant
# 400      401                                     Capacity Building Grant
#
#                             DEVELOPER_NAME                 ADDRESS  \
# 0                             Project HOME           1315 N 8TH ST
# 1                          Nueva Esperanza        3921-61 N 5TH ST
# 2              NewCourtland Elder Services          3232 HENRY AVE
# 3                                     HACE  161-71 W ALLEGHENY AVE
# 4                   Presby's Inspired Life         447 CANTRELL ST
# ..                                     ...                     ...
# 396               Octavia Hill, Youthbuild            Point Breeze
# 397  11260 Housing Development Corporation         3512 N BROAD ST
# 398                               HERO Inc         3338 N GRATZ ST
# 399                               Interact            486 GREEN LN
# 400                                   PCAH          59 N FELTON ST
#
#       PROJECT_TYPE TOTAL_UNITS ACCESSIBLE_UNITS SENSORY_UNITS VISITABLE_UNITS  \
# 0    Special Needs          30                4             2              30
# 1           Rental          38                6             2              38
# 2           Rental          49                6             2              49
# 3           Rental          81               10             2              60
# 4           Rental          61                8             4              61
# ..             ...         ...              ...           ...             ...
# 396         Rental          22
# 397  Special Needs           3
# 398  Special Needs           1
# 399  Special Needs           8
# 400  Special Needs           1
#
#     geometry
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ..       ...
# 396     None
# 397     None
# 398     None
# 399     None
# 400     None
#
# [401 rows x 11 columns]

# %%
affhousing.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OBJECTID              401 non-null    object
#  1   FISCAL_YEAR_COMPLETE  401 non-null    object
#  2   PROJECT_NAME          401 non-null    object
#  3   DEVELOPER_NAME        401 non-null    object
#  4   ADDRESS               401 non-null    object
#  5   PROJECT_TYPE          401 non-null    object
#  6   TOTAL_UNITS           401 non-null    object
#  7   ACCESSIBLE_UNITS      401 non-null    object
#  8   SENSORY_UNITS         401 non-null    object
#  9   VISITABLE_UNITS       401 non-null    object
#  10  geometry              0 non-null      geometry
# dtypes: geometry(1), object(10)
# memory usage: 34.6+ KB

# %% [markdown]
# As seen by the initial look at data, there are 11 different variables included in the dataset and 401 observations. On initial glance, that means there are 401 projects (of all types) that received subsidization from the City of Philadelphia over the past 25 years. Another column includes the total number of units, which should be much larger to account for multifamily properties. All of the variable types are object, which means there is likely a mix of numbers and strings. This type makes sense for addresses and developer names, but there are other numerical fields that are listed as object, like total units.

# %%
affhousing.head()
# Out:
#   OBJECTID FISCAL_YEAR_COMPLETE                           PROJECT_NAME  \
# 0        1                 2019  Gloria Casarez Residence (1315 N 8th)
# 1        2                 2019                 Roberto Clemente Homes
# 2        3                 2019           Henry Avenue Senior Campus I
# 3        4                 2019                      Villas Del Caribe
# 4        5                 2019                         Cantrell Place
#
#                 DEVELOPER_NAME                 ADDRESS   PROJECT_TYPE  \
# 0                 Project HOME           1315 N 8TH ST  Special Needs
# 1              Nueva Esperanza        3921-61 N 5TH ST         Rental
# 2  NewCourtland Elder Services          3232 HENRY AVE         Rental
# 3                         HACE  161-71 W ALLEGHENY AVE         Rental
# 4       Presby's Inspired Life         447 CANTRELL ST         Rental
#
#   TOTAL_UNITS ACCESSIBLE_UNITS SENSORY_UNITS VISITABLE_UNITS geometry
# 0          30                4             2              30     None
# 1          38                6             2              38     None
# 2          49                6             2              49     None
# 3          81               10             2              60     None
# 4          61                8             4              61     None

# %% [markdown]
# Based on the initial five rows, it seems like there are fairly large rental housing complexes that received funding. Right now the range of units is from 30 to 81. However, there is a distinction between total units and visitable units. I wonder if the visitable refers to affordable units vs. market-rate units? I wonder if visitable implies a certain quality/standard of housing. There are significantly fewer accessible units, which would be a major concern. One final observation in this first set is that there is variation in the name of the developer, so at least one organization doesn't have a monopoly on development funds. Also, given the first five observations were completed in 2019, I anticipate that this dataset begins with the most recent projects.

# %%
affhousing.tail()
# Out:
#     OBJECTID FISCAL_YEAR_COMPLETE               PROJECT_NAME  \
# 396      397                 1995  Youthbuild - Point Breeze
# 397      398                         Capacity Building Grant
# 398      399                         Capacity Building Grant
# 399      400                         Capacity Building Grant
# 400      401                         Capacity Building Grant
#
#                             DEVELOPER_NAME          ADDRESS   PROJECT_TYPE  \
# 396               Octavia Hill, Youthbuild     Point Breeze         Rental
# 397  11260 Housing Development Corporation  3512 N BROAD ST  Special Needs
# 398                               HERO Inc  3338 N GRATZ ST  Special Needs
# 399                               Interact     486 GREEN LN  Special Needs
# 400                                   PCAH   59 N FELTON ST  Special Needs
#
#     TOTAL_UNITS ACCESSIBLE_UNITS SENSORY_UNITS VISITABLE_UNITS geometry
# 396          22                                                    None
# 397           3                                                    None
# 398           1                                                    None
# 399           8                                                    None
# 400           1                                                    None

# %% [markdown]
# Interestingly enough, out of the final five records, only one project has a year completed. I wonder if the others are in-progress or were never finished. Or if a "capacity-building grant" means that funds are dedicated to organizational development rather than a specific project. These projects have much lower unit counts than the first five records, and there are no visitable, accessible, or sensory units listed.

# %%
affhousing.sample(10)
# Out:
#     OBJECTID FISCAL_YEAR_COMPLETE                             PROJECT_NAME  \
# 301      302                 2001                         Homestart Mantua
# 242      243                 2003  Cecil B. Moore Homeownership Zone I-A-1
# 25        26                 2016                       Winghocking Street
# 275      276                 2002                    Homestart Lower Tioga
# 71        72                 2012        Gloria's Place/3902 Spring Garden
# 354      355                 1998                            Station House
# 48        49                 2014         John Anderson/William Way Senior
# 400      401                                       Capacity Building Grant
# 215      216                 2004                    Belmont Affordable IV
# 296      297                 2001                           APM Townhouses
#
#     DEVELOPER_NAME                 ADDRESS   PROJECT_TYPE TOTAL_UNITS  \
# 301           PHDC   3816-18 FAIRMOUNT AVE  Homeownership           1
# 242   CBM HDC/PHDC       1623-31 N 18TH ST  Homeownership           3
# 25    Nicetown CDC  2006 W WINGOHOCKING ST  Homeownership           2
# 275           PHDC  1235 W WESTMORELAND ST  Homeownership           4
# 71             PEC   3902 SPRING GARDEN ST  Special Needs          11
# 354       Ingerman         2601 N BROAD ST  Special Needs         108
# 48        Pennrose        249-57 S 13TH ST         Rental          56
# 400           PCAH          59 N FELTON ST  Special Needs           1
# 215  TJ Properties         4221 PARRISH ST         Rental          11
# 296            APM           2147 N 7TH ST  Homeownership           8
#
#     ACCESSIBLE_UNITS SENSORY_UNITS VISITABLE_UNITS geometry
# 301                                                    None
# 242                                                    None
# 25                                                     None
# 275                                                    None
# 71                                                     None
# 354                                                    None
# 48                                                     None
# 400                                                    None
# 215                                                    None
# 296                                                    None

# %% [markdown]
# In looking at a sample of 10 records in the dataset, there are several repeated developers - Project Home and PCAH. There are also funds spent on homeownership projects, which are usually not affordable housing priorities. I wonder if the location of these units shows any specific type of pattern. Similar to the last five records in the full dataset, none of the projects sampled have units listed under accessible, sensory, or visitable. I wonder now if these are newer fields.

# %% [markdown]
# Now, to get a sense of trends or patterns in the dataset overall, I am going to look at the shape of the dataset. The first and most general step is affhousing.plot().

# %%
affhousing.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# As mentioned in one of the initial steps looking at the type of each variable, all the variables are objects. It would make sense that they do not show up on a graph because they are not considered numerical. However, some of these categories should be given that they are integers (unit types).

# %% [markdown]
# To try a potential other route to exploring trends in the dataset, I am going to look at subsetting rental properties.

# %%
affhousing[affhousing.PROJECT_TYPE == 'Rental']
# Out:
#     OBJECTID FISCAL_YEAR_COMPLETE                  PROJECT_NAME  \
# 1          2                 2019        Roberto Clemente Homes
# 2          3                 2019  Henry Avenue Senior Campus I
# 3          4                 2019             Villas Del Caribe
# 4          5                 2019                Cantrell Place
# 5          6                 2019       Ann Thomas Presbyterian
# ..       ...                  ...                           ...
# 392      393                 1995            Lower Germantown I
# 393      394                 1995               Mansion Court I
# 394      395                 1995               Model Cities #6
# 395      396                 1995                Sarah Allen II
# 396      397                 1995     Youthbuild - Point Breeze
#
#                      DEVELOPER_NAME                 ADDRESS PROJECT_TYPE  \
# 1                   Nueva Esperanza        3921-61 N 5TH ST       Rental
# 2       NewCourtland Elder Services          3232 HENRY AVE       Rental
# 3                              HACE  161-71 W ALLEGHENY AVE       Rental
# 4            Presby's Inspired Life         447 CANTRELL ST       Rental
# 5            Presby's Inspired Life          2000 S 58TH ST       Rental
# ..                              ...                     ...          ...
# 392                           GGHDC               Scattered       Rental
# 393                        Pennrose          1800 N 32ND ST       Rental
# 394            Michaels Development          2200 N 13TH ST       Rental
# 395  Friends Rehabilitation Program         4035 PARRISH ST       Rental
# 396        Octavia Hill, Youthbuild            Point Breeze       Rental
#
#     TOTAL_UNITS ACCESSIBLE_UNITS SENSORY_UNITS VISITABLE_UNITS geometry
# 1            38                6             2              38     None
# 2            49                6             2              49     None
# 3            81               10             2              60     None
# 4            61                8             4              61     None
# 5            75               75             3              75     None
# ..          ...              ...           ...             ...      ...
# 392          50                                                    None
# 393          31                                                    None
# 394          70                                                    None
# 395          36                                                    None
# 396          22                                                    None
#
# [176 rows x 11 columns]

# %% [markdown]
# It looks like out of the total 401 records of affordable housing projects, a little under half are rental housing. While this seems to be surprising at initial glance, there is another category for special needs housing.

# %%
affhousing[affhousing.PROJECT_TYPE == 'Special Needs']
# Out:
#     OBJECTID FISCAL_YEAR_COMPLETE                           PROJECT_NAME  \
# 0          1                 2019  Gloria Casarez Residence (1315 N 8th)
# 7          8                 2018                      The Lofts at 2601
# 10        11                 2018                    Ruth Williams House
# 11        12                 2018                           Tioga Family
# 18        19                 2016                    St. Raymond's House
# ..       ...                  ...                                    ...
# 386      387                 1995                        Germantown YMCA
# 397      398                                     Capacity Building Grant
# 398      399                                     Capacity Building Grant
# 399      400                                     Capacity Building Grant
# 400      401                                     Capacity Building Grant
#
#                             DEVELOPER_NAME             ADDRESS   PROJECT_TYPE  \
# 0                             Project HOME       1315 N 8TH ST  Special Needs
# 7                    Volunteers of America     2601 N BROAD ST  Special Needs
# 10                            Project HOME  2413-29 N BROAD ST  Special Needs
# 11                    Gaudenzia Foundation  1822-26 W TIOGA ST  Special Needs
# 18                              Depaul USA      1330 VERNON RD  Special Needs
# ..                                     ...                 ...            ...
# 386                           Germantown Y      5722 GREENE ST  Special Needs
# 397  11260 Housing Development Corporation     3512 N BROAD ST  Special Needs
# 398                               HERO Inc     3338 N GRATZ ST  Special Needs
# 399                               Interact        486 GREEN LN  Special Needs
# 400                                   PCAH      59 N FELTON ST  Special Needs
#
#     TOTAL_UNITS ACCESSIBLE_UNITS SENSORY_UNITS VISITABLE_UNITS geometry
# 0            30                4             2              30     None
# 7            56                6             2              14     None
# 10           88               10             4              88     None
# 11           24                                                    None
# 18           28                2             2              28     None
# ..          ...              ...           ...             ...      ...
# 386         128                                                    None
# 397           3                                                    None
# 398           1                                                    None
# 399           8                                                    None
# 400           1                                                    None
#
# [116 rows x 11 columns]

# %% [markdown]
# As expected, there are a good number of "special needs" properties, which when combined with "rental properties" makes up the majority of property types.

# %%
116+176
# Out:
# 292

# %%
(292/401)*100
# Out:
# 72.81795511221945

# %% [markdown]
# Roughly 73% of the affordable housing projects were for rental or special needs housing. Just to confirm that the remaining units are for homeownership programs, let's check!

# %%
affhousing.query("PROJECT_TYPE == 'Homeownership'")
# Out:
#     OBJECTID FISCAL_YEAR_COMPLETE                         PROJECT_NAME  \
# 22        23                 2016      Ingersoll Commons Homeownership
# 25        26                 2016                   Winghocking Street
# 28        29                 2015            Cross/Greenwich - Habitat
# 30        31                 2015                         Latona Green
# 35        36                 2014  North Phila Complete Blocks - Gratz
# ..       ...                  ...                                  ...
# 307      308                 2001                 Poplar Nehemiah II-B
# 308      309                 2001                            Villa III
# 309      310                 2001                        Village Homes
# 310      311                 2001                      Wilmont Meadows
# 311      312                 2001                           YouthBuild
#
#                          DEVELOPER_NAME                 ADDRESS  \
# 22                   Community Ventures       1301 N SMEDLEY ST
# 25                         Nicetown CDC  2006 W WINGOHOCKING ST
# 28                 Habitat for Humanity           2325 CROSS ST
# 30                 Innova Redevelopment          1231 S 17TH ST
# 35                 Habitat for Humanity         1815 N GRATZ ST
# ..                                  ...                     ...
# 307          Poplar Enterprise Dev Corp         1206 PARRISH ST
# 308                     Nueva Esperanza    1322-40 N HANCOCK ST
# 309  Village of the Arts and Humanities    1012 W HUNTINGDON ST
# 310                       Frankford CDC          1815 WILMOT ST
# 311                               GGHDC        349 HANSBERRY ST
#
#       PROJECT_TYPE TOTAL_UNITS ACCESSIBLE_UNITS SENSORY_UNITS VISITABLE_UNITS  \
# 22   Homeownership          10
# 25   Homeownership           2
# 28   Homeownership           6
# 30   Homeownership          10
# 35   Homeownership           1
# ..             ...         ...              ...           ...             ...
# 307  Homeownership          57
# 308  Homeownership           7
# 309  Homeownership           6
# 310  Homeownership          15
# 311  Homeownership           4
#
#     geometry
# 22      None
# 25      None
# 28      None
# 30      None
# 35      None
# ..       ...
# 307     None
# 308     None
# 309     None
# 310     None
# 311     None
#
# [109 rows x 11 columns]

# %% [markdown]
# Yep! The remaining 109 records are homeownership projects. Another way to look at this is through the value_counts function and to look specifically at project type.

# %%
affhousing.value_counts('PROJECT_TYPE')
# Out:
# PROJECT_TYPE
# Rental           176
# Special Needs    116
# Homeownership    109
# dtype: int64

# %% [markdown]
# I also want to potentially created a smaller subset of data with the five variables that could help answer the overall question about how funds are being spent-- on what type of projects? where? and what are the implications?

# %%
desired_columns = ['OBJECTID','PROJECT_NAME','FISCAL_YEAR_COMPLETE','ADDRESS','PROJECT_TYPE','TOTAL_UNITS']

affhousing[desired_columns].sample(5)
# Out:
#     OBJECTID               PROJECT_NAME FISCAL_YEAR_COMPLETE  \
# 103      104  Pennsdale II Rent Reserve                 2011
# 337      338      Bethesda Transitional                 1999
# 16        17              Lindley Court                 2017
# 323      324             Haddington III                 2000
# 214      215        St. Ignatius Senior                 2004
#
#                     ADDRESS   PROJECT_TYPE TOTAL_UNITS
# 103        4200 MITCHELL ST         Rental          10
# 337           816 S 20TH ST  Special Needs          16
# 16       1300 W LINDLEY AVE         Rental          48
# 323  Haddington - Scattered  Special Needs          20
# 214   4400-58 FAIRMOUNT AVE         Rental          67

# %%
ah_trimmed = affhousing[desired_columns].copy()
ah_trimmed
# Out:
#     OBJECTID                           PROJECT_NAME FISCAL_YEAR_COMPLETE  \
# 0          1  Gloria Casarez Residence (1315 N 8th)                 2019
# 1          2                 Roberto Clemente Homes                 2019
# 2          3           Henry Avenue Senior Campus I                 2019
# 3          4                      Villas Del Caribe                 2019
# 4          5                         Cantrell Place                 2019
# ..       ...                                    ...                  ...
# 396      397              Youthbuild - Point Breeze                 1995
# 397      398                Capacity Building Grant
# 398      399                Capacity Building Grant
# 399      400                Capacity Building Grant
# 400      401                Capacity Building Grant
#
#                     ADDRESS   PROJECT_TYPE TOTAL_UNITS
# 0             1315 N 8TH ST  Special Needs          30
# 1          3921-61 N 5TH ST         Rental          38
# 2            3232 HENRY AVE         Rental          49
# 3    161-71 W ALLEGHENY AVE         Rental          81
# 4           447 CANTRELL ST         Rental          61
# ..                      ...            ...         ...
# 396            Point Breeze         Rental          22
# 397         3512 N BROAD ST  Special Needs           3
# 398         3338 N GRATZ ST  Special Needs           1
# 399            486 GREEN LN  Special Needs           8
# 400          59 N FELTON ST  Special Needs           1
#
# [401 rows x 6 columns]

# %% [markdown]
# Now that I have an initial understanding of the type of programs these funds supported, I still want to *try* to get a sense of their spatial location. While the plotting above was a little disappointing, I am going to see if it's possible to use folium to see these projects I begin by importing the folium library. I import the folium libaray and save the initial basemap as m.

# %%
import folium
m = folium.Map()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f26c5c2e454d8a609f8561238a295fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f26c5c2e454d8a609f8561238a295fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f26c5c2e454d8a609f8561238a295fe = L.map(
#                 &quot;map_3f26c5c2e454d8a609f8561238a295fe&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d116110a16f51dee361a68ad329cc07a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3f26c5c2e454d8a609f8561238a295fe);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, I have an intitial interactive map, but I am concerned about the limited locational data that I have. When I tried to run ' m = folium.Map(location=['ADDRESS']), I received an error because it seems that latitude and longitude are the required format. I only have a street address for properties with no city, state, zip code, or lat/long. It seems like there are geocoding scripts that will convert addresses into lat and long, but that might be a step for next time.
#
# However, because I know these data points are in Philadelphia, I can work on getting the frame set up. The internet lists the lat and long for Philadelphia as "39.95233, -75.16379," so I will use these for the folium command below.

# %%
folium.Map(location=[39.95233, -75.16379],tiles="Stamen Toner", zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ba1c2cf89426337bc3e166803a8945d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ba1c2cf89426337bc3e166803a8945d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ba1c2cf89426337bc3e166803a8945d = L.map(
#                 &quot;map_6ba1c2cf89426337bc3e166803a8945d&quot;,
#                 {
#                     center: [39.95233, -75.16379],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e61d8f0e5470555972a80810d43a5120 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6ba1c2cf89426337bc3e166803a8945d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# My next steps in this project are to attempt to geocode the address data to use for folium mapping and to investigate how to convest object types into integers to conduct some summary statistics (if needed)!
